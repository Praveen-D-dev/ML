# %%
import numpy as n
import pandas as p
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import LabelEncoder

# %%
data=p.read_csv("/content/crop_yield_data.csv")

# %%
data.isnull().sum()
# Out:
# rainfall_mm           0
# soil_quality_index    0
# farm_size_hectares    0
# sunlight_hours        0
# fertilizer_kg         0
# crop_yield            0
# dtype: int64

# %%
data.head()
# Out:
#    rainfall_mm  soil_quality_index  farm_size_hectares  sunlight_hours  \
# 0         1626                   9                 636              11
# 1         1959                   9                  73              11
# 2         1360                   1                 352               5
# 3         1794                   2                 948               7
# 4         1630                   5                 884               5
#
#    fertilizer_kg  crop_yield
# 0           1006         404
# 1            112         115
# 2            702         231
# 3            299         537
# 4           2733         554

# %%
a=data[["rainfall_mm","soil_quality_index","farm_size_hectares","sunlight_hours","fertilizer_kg"]]
b=data["crop_yield"]

# %%
L=LinearRegression()

# %%
L.fit(a,b)
# Out:
# LinearRegression()

# %%
print("Your Yield in Crop will be ",L.predict([[1500,8,534,10,829]]))
# Out:
# Your Yield in Crop will be  [343.57335233]
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
